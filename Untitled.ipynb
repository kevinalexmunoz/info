# %%
class Microorganimo: 
    def __init__(self):         

        self.__numero = 0
        self.__fila = 0
        self.__columna = 0
        self.__conservacion = ""
        self.__peligroso =""
        self.__tipo=""
        
    def verTipo(self):
        return self.__tipo
    def asignarTipo(self,v):
        self.__tipo=v

    def verNumero(self):
        return self.__numero

    def verColumna(self):
        return self.__columna
    def verFila(self):
        return self.__fila    
    def verConservacion(self):
        return self.__conservacion
    def verPeligroso(self):
        return self.__peligroso


    def asignarNumero(self, hc):
        self.__numero = hc 

    def asignarColumna(self, c):
        self.__columna = c
    def asignarFila(self, f):
        self.__fila = f
    def asignarConservacion(self, m):
        self.__conservacion = m
    def asignarPeligroso(self, p):
        self.__peligroso = p


class bacterias(Microorganimo):
    def __init__(self, numero, fila, columna, conservacion, peligroso):
        super().__init__(numero, fila, columna, conservacion, peligroso)
        self.__gran = ""
        self.__forma = ""

    def verGram(self):
        return self.__gran
    def asignarGram(self,g):
        self.__gran = g

    def verForma(self):
        return self.__forma
    def asignarForma(self,f):
        self.__forma = f
        
class Virus(Microorganimo):
    def __init__(self, numero, fila, columna, conservacion, peligroso):
        super().__init__(numero, fila, columna, conservacion, peligroso)
        self.__infecion = ""
        self.__huesped = ""
        
    def verInfecion(self):
        return self.__infecion
    def asignarInfecion(self,i):
        self.__infecion = i

    def verHuesped(self):
        return self.__huesped
    def asignarHuesped(self,h):
        self.__huesped= h

class Priones(Microorganimo):
    def __init__(self, numero, fila, columna, conservacion, peligroso):
        super().__init__(numero, fila, columna, conservacion, peligroso)
        self.__origen = ""
        self.__peligrosidad = 0
        

    def verOrigen(self):
        return self.__origen
    def asignarOrigen(self,o):
        self.__origen = o

    def verPeli(self):
        return self.__peligrosidad
    def asignarPeli(self,ph):
        self.__peligrosidad= ph
        
class Otros(Microorganimo):
    def __init__(self, numero, fila, columna, conservacion, peligroso):
        super().__init__(numero, fila, columna, conservacion, peligroso)
        self.__nombre = ""
        self.__reino = ""
        self.__descripcion = ""
        

    def verNombree(self):
        return self.__nombre
    def asignarNombree(self,n):
        self.__nombre = n

    def verReino(self):
        return self.__reino
    def asignarPeli(self,re):
        self.__reino = re
        
    def verDescripcion(self):
        return self.__descripcion
    def asignarDescripcion(self,de):
        self.__descripcion = de
        
 


########################################################################################################################
class Sistema(object):
    def __init__(self):

        self.__lista_Microorganismos = []
    def verificarExiste(self,c):
        return c in self.__lista_Microorganismos

    def ingresarMicroorganismo(self,p):
        self.__lista_Microorganismos.append(p)


    def eliminarMicroorganismo(self, numero):
        #Es for paciente y no cedula porque en la lista hay pacientes no numeros 
        for micro in self.__lista_Microorganismos: 
            if numero == micro.verNumero():
                #del self.__lista_Microorganismos(micro)
                return True
        return False

    
    def verDatos(self):
        
        #Es for paciente y no cedula porque en la lista hay pacientes no numeros 
        for organismo in self.__lista_Microorganismos: 
            print("numero: " + str(organismo.verNumero()))
            print("tipo: " + str(organismo.verTipo()))
            print("fila: " + str(organismo.verFila()))
            print("columna: " + str(organismo.verColumna()))
            print("conservacion" + organismo.verConservacion())
            print("peligroso" + organismo.verPeligroso())


    def salir(self):
        print("Saliendo del sistema...")
        

        
        
def validar(ms):
    while True:
        try:
            valor = int(input(ms))
            break
        except ValueError:
            print("Ingrese un dato numérico...")
    return valor

def main():

    tema = Sistema()
    
    while True:

        opcion = input('''
_______________________________
             Menu:
_______________________________
    1. Ingresar un Microorganismo
    2. Ver microorganimos
    5. Eliminar un Microorganismo
    6. Salir
 Opcion: ''')

        if opcion == "1":
            num = validar("Ingrese el numero del micoorganismo:")
            if tema.verificarExiste(num) == True:
                print(f"Microorganismo ya esta en el sistema...verifique el numero ingresado {num}")
                continue
            else:
                

                Tipo = int(input("Ingrese el tipo de microorganismo(numero) 1. bacteira, 2. virus, 3.priones, 4.otros "))
                if Tipo == 1:
                    gran = input("es gran positivo o negativo")
                    forma = input("forma de la bacteria")
                    
                    Tipo = (gran, forma)

                elif Tipo == 2:
                    infeccion = input("tipo de infeccion")
                    huesped = input("ingrese el huesped favorito")
                        
                    Tipo = (infeccion, huesped)
                elif Tipo == 3:
                    origen = input("origen: ")
                    peligrosidad = int(input("del 1 al 5 nivel de peligrosidad"))
                        
                    Tipo = (origen, peligrosidad)
                elif Tipo == 4: 
                    nombre = input("ingrese el nombre")
                    reino = input("ingrese el reino animal")
                    descripcion = input("descibalo")
                    Tipo = (nombre, reino, descripcion)
                else:
                    print("eliga una opcion correcta")
                    
                columna= validar("Ingrese COLUMNA:")
                fila = validar("IngreseFILA:")
                conservacion = input("Ingrese el conservacion:")
                peligroso = input("es peligroso:")


                m = Microorganimo() 

                m.asignarNumero(num)
                m.asignarColumna(columna)
                m.asignarFila(fila)
                m.asignarConservacion(conservacion)
                m.asignarPeligroso(peligroso)
                m.asignarTipo(Tipo)
                
                tema.ingresarMicroorganismo(m)

            
        

            resultado = tema.ingresarMicroorganismo(m)
            #if resultado == True:
                #print("\nEl microorganismo fue ingresada con exito")
            #else:
                #print("\nEl microorganismo ya se encuentra en el sistema")
        

            
        elif opcion == "2":
            tema.verDatos()

        elif opcion == "3":
            q= int(input("Ingrese el dofigo a eliminar"))
 
            resultado_operacion = tema.eliminarMicroorganismo(q) 
            if resultado_operacion == True:
                print("eliminado del sistema con exito")
            else:
                print("No se ha podido eliminar ")

        elif opcion == "4":
            tema.salir()
            break
        else:
            print("Opcion no valida")



if __name__ == '__main__':
    main()
# Out:
# _______________________________
#              Menu:
# _______________________________
#     1. Ingresar un Microorganismo
#     2. Ver microorganimos
#     5. Eliminar un Microorganismo
#     6. Salir
#  Opcion: 1
# Ingrese el numero del micoorganismo:1
# Ingrese el tipo de microorganismo(numero) 1. bacteira, 2. virus, 3.priones, 4.otros 1
# es gran positivo o negativo1
# forma de la bacteria1
# Ingrese COLUMNA:1
# IngreseFILA:1
# Ingrese el conservacion:1
# es peligroso:1
#
# _______________________________
#              Menu:
# _______________________________
#     1. Ingresar un Microorganismo
#     2. Ver microorganimos
#     5. Eliminar un Microorganismo
#     6. Salir
#  Opcion: 1
# Ingrese el numero del micoorganismo:2
# Ingrese el tipo de microorganismo(numero) 1. bacteira, 2. virus, 3.priones, 4.otros 2
# tipo de infeccion2
# ingrese el huesped favorito2
# Ingrese COLUMNA:2
# IngreseFILA:2
# Ingrese el conservacion:2
# es peligroso:2
#
# _______________________________
# ...

# %% [markdown]
# ##
